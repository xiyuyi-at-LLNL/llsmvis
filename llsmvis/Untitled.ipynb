# %% [markdown]
# testing group1 from here
#
# /p/lscratchh/yi10/20201020-calib-RAW264.7
#
# get get mp4 output.

# %%
#!/g/g92/yi10/anaconda3/bin/python
import sys
sys.path.append("/g/g92/yi10")
from llsmvis import *
from llsmvis import utils
import skvideo.io
import warnings; warnings.simplefilter('ignore')
if WARNINGS_OFF:
    import warnings
    warnings.filterwarnings("ignore")

print('\n\n====================  deskew =======================')

# define fpath and name_head [should modify from bash]
fpath = "/p/lscratchh/yi10/20201020-calib-RAW264.7"
fname_head = "group2"

# get a parser:
p = LLSMParser(fpath, fname_head)

# if VERBOSE:
#     print('check basic info of this parser')
#     p.info()

# # define the deskewer
# d = Deskewer(p)

# # deskew all the tiffs
# d.deskew_all_tiffs()
# Out:
# ====================  deskew =======================
# ['/p/lscratchh/yi10/20201020-calib-RAW264.7/results_dsk/group2_deskewed/Deskewed_group2_ch0_stack0001_3nm_0023099msec_0045412556msecAbs.tif', '/p/lscratchh/yi10/20201020-calib-RAW264.7/results_dsk/group2_deskewed/Deskewed_group2_ch0_stack0000_3nm_0000000msec_0045389457msecAbs.tif', '/p/lscratchh/yi10/20201020-calib-RAW264.7/results_dsk/group2_deskewed/Deskewed_group2_ch0_stack0002_3nm_0046198msec_0045435655msecAbs.tif']
# length of all tiffs is3
# setting t1
# setting t2

# %%
[fig, ax] = utils.render_mpl_table(p, p.data_properties, header_columns=0, col_width=7.0)
utils.getLabeledXYmip_MP4(p, 0, 1, channel_inds=None)
# Out:
# /p/lscratchh/yi10/20201020-calib-RAW264.7/results_dsk/group2_deskewed/MIP_channel0_XY.tif
# maximum is:1.3773584905660377
# (3, 1024, 1472)
