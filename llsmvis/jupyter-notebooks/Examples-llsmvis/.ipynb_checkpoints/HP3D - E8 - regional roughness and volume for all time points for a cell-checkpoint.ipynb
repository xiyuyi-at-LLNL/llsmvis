# %% [markdown]
# ## 1. Import tools

# %%
import sys
sys.path.append('/g/g92/miao1/Development/llsmvis')
sys.path.append('/Users/yi10/Desktop/Research/Software/T-llsmvis/')
sys.path.append('/g/g92/yi10')
import llsmvis
from llsmvis.extensions import hp3d
from llsmvis.extensions.hp3d import surface_morphometrics as sm
from llsmvis.extensions.hp3d import masscenter as mc
from llsmvis.extensions.hp3d import croproi3d as c3d
import h5py
import os
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
import vtk
from vtk.util import numpy_support
from llsmvis.extensions.hp3d import tools_vectorsets as v
from scipy.interpolate import griddata

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 2. Define parameters

# %%
# ticket information (the output files from the interactive trimming results, see E1 for details)
tpath='/p/lustre2/yi10/hp3d/CroppingData'
thead='2021-11-10-cell1'  
hp3dpath='/p/lustre2/yi10/hp3d'
cellstlspath=os.path.join(hp3dpath,thead,'surface_extraction')
conecutspath=os.path.join(hp3dpath,thead,'cone_cuts_analysis')
try:
    os.mkdir(conecutspath)
except:
    pass


# define parametres for the choice of cone set:
apex_angle=40 # apex angle of the cone, degree.
# fnorm_for_cone=sm.get_f_norm(40)
fnorm_for_cone=1
sample_angle=15 # sampling angle when choose semi-equal spaced points.
conespath='/p/lscratchh/yi10/hp3d/cones/cones_CenterSpacingAngle'+str(sample_angle)+'_ConeApexAngle'+str(apex_angle)
# Define equaliy spaced vectors to be used as the direcitonal vector for the cones
xs,ys,zs=v.sample_points_semi_equal_space(sample_angle)
print("total number of points: " +str(len(xs)))
# define all cone stl paths
coneind=0
conestlpaths=[]
for x,y,z in zip(xs, ys, zs):
    conestlpath=os.path.join(conespath,'cone_pos'+str(coneind)+'.stl')
    conestlpaths.append(conestlpath)
    coneind+=1
    

# define mapping interpolation coordinates
# make the current location coordinates into the format of points for interpolation
points=np.asarray([xs,ys,zs]).T

# define location points to interpolate for
request=v.sample_points_equal_spaced_logi_lati(longitude_n=360, latitude_n=180).T


# get the list of stl paths for all the cells
allcellstls=c3d.get_cell_stl_list(hp3dpath=hp3dpath, thead=thead)
# Out:
# total number of points: 184

# %% [markdown]
# ## 3. Perform patch-wise r/v calculations
# calculate the patch-wise roughness and volumes as cropped by cones

# %%
cell_time_ind = 0

# input cellstlpath
cellstlpath=allcellstls[cell_time_ind]

# define output dir for the cut .stl files.
cuts_output_dir = os.path.join(conecutspath,'time'+str(cell_time_ind).zfill(4))
try:
    os.mkdir(cuts_output_dir)
except:
    pass

# define shifted cell stl path
shiftedcellstl=os.path.join(cuts_output_dir,'shiftedcell.stl')
# calculate the shifted cell stl
sm.get_shifted_cell(cellstlpath,output=shiftedcellstl,savestl=True)

# loop over each cone, extract patch wise roughness and volume with all the cone-cuts
d={}
d.update({'content':'patch wise roughness and cone volume analysis results for one 3D volume'})

roughnesses=[]
conevolumes=[]
for cone_index in np.arange(0,len(conestlpaths)):
# for cone_index in [0]:
    print('cut with cone #'+str(cone_index))
    
    # load the cone polydata and cell polydata
    stlpath = conestlpaths[cone_index]
    conepolydata=sm.stl2polydata(stlpath)
    cellpolydata=sm.stl2polydata(shiftedcellstl)
    
    # define the cut output file names
    cut_cell=os.path.join(cuts_output_dir,'cut_cell_cone'+str(cone_index)+'.stl')
    cellprot=os.path.join(cuts_output_dir,'protrusion_cone'+str(cone_index)+'.stl')
    coneprot=os.path.join(cuts_output_dir,'cone_n_protrusion_cone'+str(cone_index)+'.stl')
    cutresult= sm.get_cut(cut_cell_fpath=cut_cell,
                        cut_protrusion_fpath=cellprot,
                        cone_protrusion_fpath=coneprot,
                        use_stl_filepaths=False,
                        cell_polydata=cellpolydata,
                        cone_polydata=conepolydata,
                        write_output_cone_protrusion_as_stl=True,
                        write_output_protrusion_as_stl=True,
                        write_output_cell_cut_as_stl=False,
                        verbose=False)
    
    sv_protrusion_only = sm.get_volume_surface_area(polydata=cutresult['protrusion polydata'], 
                                                    usestl=False, returnfmt='dict', verbose=False)

    sv_protrusion_cone = sm.get_volume_surface_area(polydata=cutresult['cone protrusion polydata'], 
                                                    usestl=False, returnfmt='dict', verbose=False)

    regional_roughness=sm.getroughness(sv_protrusion_only['surface area'],
                                       sv_protrusion_cone['volume'], 
                                       f_norm=fnorm_for_cone)

    print('regional roughness: ' + str(regional_roughness) +', cone #'+str(cone_index))
    roughnesses.append(regional_roughness)
    conevolumes.append(sv_protrusion_cone['volume'])
    
# make the current roughnesses into the correct format of points for interpolation
values_roughnesses = np.asarray(roughnesses)
values_conevolumes = np.asarray(conevolumes)

# Map interpolation
roughnesses_map = griddata(points, values_roughnesses, request,'nearest').reshape(180, 360)
conevolumes_map = griddata(points, values_conevolumes, request,'nearest').reshape(180, 360)

d.update({'cones stl paths': conestlpaths})
d.update({'roughnesses on cone vectors': roughnesses})
d.update({'conevolumes on cone vectors': conevolumes})
d.update({'roughnesses on map': roughnesses_map})
d.update({'conevolumes on map': conevolumes_map})

# we are going to have each cell and each time point to be calculated in parallel, so here it won't be directly organized in to the hp3d data.
# we will save out the specific hdf5 files per cell per time point.

h5fname=os.path.join(cuts_output_dir, 'patch-wise-roughness-volumes.hdf5')
try: 
    os.remove(h5fname)
except:
    pass
f = h5py.File(h5fname, 'w')
f.create_dataset("roughnesses on cone vectors", data=roughnesses, dtype='float')
f.create_dataset("cone volumes on cone vectors", data=conevolumes, dtype='float')
f.create_dataset("roughnesses on map", data=roughnesses_map, dtype='float')
f.create_dataset("cone volumes on map", data=conevolumes_map, dtype='float')
f.create_dataset("cones stl paths",data=conestlpaths)
f.close()
# Out:
# <vtkmodules.vtkCommonDataModel.vtkPolyData(0x5555581676b0) at 0x2aab0064bfa0>
# cut with cone #0
# regional roughness: 1.5423030051017543, cone #0
# cut with cone #1
# regional roughness: 1.6433617600785098, cone #1
# cut with cone #2
# regional roughness: 1.5929271774072813, cone #2
# cut with cone #3
# regional roughness: 1.5392874247508357, cone #3
# cut with cone #4
# regional roughness: 1.5037129863723016, cone #4
# cut with cone #5
# regional roughness: 1.5525814394386113, cone #5
# cut with cone #6
# regional roughness: 1.6435842327221375, cone #6
# cut with cone #7
# regional roughness: 1.6284943010090016, cone #7
# cut with cone #8
# regional roughness: 1.6406871562902345, cone #8
# cut with cone #9
# regional roughness: 1.6604973965009011, cone #9
# cut with cone #10
# regional roughness: 1.624707901142703, cone #10
# cut with cone #11
# regional roughness: 1.612139165948735, cone #11
# cut with cone #12
# regional roughness: 1.536939399929329, cone #12
# cut with cone #13
# regional roughness: 1.5432665100424487, cone #13
# cut with cone #14
# regional roughness: 1.5401857268933836, cone #14
# cut with cone #15
# regional roughness: 1.631111011139391, cone #15
# cut with cone #16
# regional roughness: 1.616879203745794, cone #16
# cut with cone #17
# regional roughness: 1.6231114105031526, cone #17
# cut with cone #18
# regional roughness: 1.6433815633790985, cone #18
# cut with cone #19
# regional roughness: 1.6416857808942185, cone #19
# cut with cone #20
# regional roughness: 1.6421812636881155, cone #20
# cut with cone #21
# regional roughness: 1.6710721227484173, cone #21
# cut with cone #22
# regional roughness: 1.6926744134293303, cone #22
# cut with cone #23
# regional roughness: 1.678858219124475, cone #23
# cut with cone #24
# regional roughness: 1.6634657036311504, cone #24
# cut with cone #25
# regional roughness: 1.671520384445477, cone #25
# cut with cone #26
# regional roughness: 1.6614343055853016, cone #26
# cut with cone #27
# regional roughness: 1.6060349045485276, cone #27
# cut with cone #28
# regional roughness: 1.6163207003318902, cone #28
# cut with cone #29
# regional roughness: 1.6396635365342027, cone #29
# cut with cone #30
# regional roughness: 1.649427291006296, cone #30
# cut with cone #31
# regional roughness: 1.6469065124039444, cone #31
# cut with cone #32
# regional roughness: 1.6274015163706304, cone #32
# cut with cone #33
# regional roughness: 1.6411388780928857, cone #33
# cut with cone #34
# regional roughness: 1.6517221958329407, cone #34
# cut with cone #35
# regional roughness: 1.6596114975441667, cone #35
# cut with cone #36
# regional roughness: 1.6729295919460598, cone #36
# cut with cone #37
# regional roughness: 1.65668489630244, cone #37
# cut with cone #38
# regional roughness: 1.6730490756353582, cone #38
# cut with cone #39
# regional roughness: 1.6940411089462626, cone #39
# cut with cone #40
# regional roughness: 1.7037145844215174, cone #40
# cut with cone #41
# regional roughness: 1.69649772463442, cone #41
# cut with cone #42
# regional roughness: 1.6919937531868314, cone #42
# cut with cone #43
# regional roughness: 1.685703855149982, cone #43
# cut with cone #44
# regional roughness: 1.6839283598268147, cone #44
# cut with cone #45
# regional roughness: 1.6834674685623177, cone #45
# cut with cone #46
# regional roughness: 1.6733089717239378, cone #46
# cut with cone #47
# regional roughness: 1.663807265688207, cone #47
# cut with cone #48
# regional roughness: 1.6597976220855173, cone #48
# cut with cone #49
# regional roughness: 1.6674769344946816, cone #49
# cut with cone #50
# regional roughness: 1.650365320904923, cone #50
# cut with cone #51
# regional roughness: 1.6631523015243013, cone #51
# cut with cone #52
# regional roughness: 1.648570845577821, cone #52
# cut with cone #53
# regional roughness: 1.649444666628533, cone #53
# cut with cone #54
# regional roughness: 1.6598224491675655, cone #54
# cut with cone #55
# regional roughness: 1.6747336258792038, cone #55
# cut with cone #56
# regional roughness: 1.680653379604978, cone #56
# cut with cone #57
# regional roughness: 1.6957083784889229, cone #57
# cut with cone #58
# regional roughness: 1.671040736524503, cone #58
# cut with cone #59
# regional roughness: 1.6872693536314984, cone #59
# cut with cone #60
# regional roughness: 1.7008279670533255, cone #60
# cut with cone #61
# regional roughness: 1.6975196747680832, cone #61
# cut with cone #62
# regional roughness: 1.7061140441395248, cone #62
# cut with cone #63
# regional roughness: 1.7107934123601922, cone #63
# cut with cone #64
# regional roughness: 1.7061622677713972, cone #64
# cut with cone #65
# regional roughness: 1.6970011017160904, cone #65
# cut with cone #66
# regional roughness: 1.6955361512158265, cone #66
# cut with cone #67
# regional roughness: 1.6942276795754938, cone #67
# cut with cone #68
# regional roughness: 1.6909055609654533, cone #68
# cut with cone #69
# regional roughness: 1.6866287038449985, cone #69
# cut with cone #70
# regional roughness: 1.6818499219912144, cone #70
# cut with cone #71
# regional roughness: 1.6841720542970557, cone #71
# cut with cone #72
# regional roughness: 1.6731098088710463, cone #72
# cut with cone #73
# regional roughness: 1.6707842137550921, cone #73
# cut with cone #74
# regional roughness: 1.6918189623160242, cone #74
# cut with cone #75
# regional roughness: 1.6619146799011153, cone #75
# cut with cone #76
# regional roughness: 1.6458481028263743, cone #76
# cut with cone #77
# regional roughness: 1.6492517228221528, cone #77
# cut with cone #78
# regional roughness: 1.6801297488737998, cone #78
# cut with cone #79
# regional roughness: 1.6959244554758803, cone #79
# cut with cone #80
# regional roughness: 1.70958577651862, cone #80
# cut with cone #81
# regional roughness: 1.702955029844502, cone #81
# cut with cone #82
# regional roughness: 1.702173368607079, cone #82
# cut with cone #83
# regional roughness: 1.706191397525979, cone #83
# cut with cone #84
# regional roughness: 1.7020319007788436, cone #84
# cut with cone #85
# regional roughness: 1.7103397862180938, cone #85
# cut with cone #86
# regional roughness: 1.7212746508149384, cone #86
# cut with cone #87
# regional roughness: 1.7186265104928786, cone #87
# cut with cone #88
# regional roughness: 1.7082994381628998, cone #88
# cut with cone #89
# regional roughness: 1.7041655697342686, cone #89
# cut with cone #90
# regional roughness: 1.7117274678802745, cone #90
# cut with cone #91
# regional roughness: 1.7078535179587626, cone #91
# cut with cone #92
# regional roughness: 1.7019652853146527, cone #92
# cut with cone #93
# regional roughness: 1.711880636461361, cone #93
# cut with cone #94
# regional roughness: 1.7087998954027606, cone #94
# cut with cone #95
# regional roughness: 1.6945698043163928, cone #95
# cut with cone #96
# regional roughness: 1.687389704753343, cone #96
# cut with cone #97
# regional roughness: 1.696360400204272, cone #97
# cut with cone #98
# regional roughness: 1.6989742400353742, cone #98
# cut with cone #99
# regional roughness: 1.6691254827131086, cone #99
# cut with cone #100
# regional roughness: 1.647457447460853, cone #100
# cut with cone #101
# regional roughness: 1.6703779179254088, cone #101
# cut with cone #102
# regional roughness: 1.7013405219905195, cone #102
# cut with cone #103
# regional roughness: 1.7100792861534018, cone #103
# cut with cone #104
# regional roughness: 1.7178851874284857, cone #104
# cut with cone #105
# regional roughness: 1.7123361103017805, cone #105
# cut with cone #106
# regional roughness: 1.6871179999848436, cone #106
# cut with cone #107
# regional roughness: 1.6780968992405532, cone #107
# cut with cone #108
# regional roughness: 1.6717186670125164, cone #108
# cut with cone #109
# regional roughness: 1.6865250419385358, cone #109
# cut with cone #110
# regional roughness: 1.7247727310264456, cone #110
# cut with cone #111
# regional roughness: 1.7195630128794912, cone #111
# cut with cone #112
# regional roughness: 1.7059379943713275, cone #112
# cut with cone #113
# regional roughness: 1.709053688870428, cone #113
# cut with cone #114
# regional roughness: 1.71274613161737, cone #114
# cut with cone #115
# regional roughness: 1.7129605260021916, cone #115
# cut with cone #116
# regional roughness: 1.7059036270771044, cone #116
# cut with cone #117
# regional roughness: 1.7142978469034937, cone #117
# cut with cone #118
# regional roughness: 1.7023687135612018, cone #118
# cut with cone #119
# regional roughness: 1.6968096986904757, cone #119
# cut with cone #120
# regional roughness: 1.6996095204593191, cone #120
# cut with cone #121
# regional roughness: 1.7048591624284701, cone #121
# cut with cone #122
# regional roughness: 1.6940056309023346, cone #122
# cut with cone #123
# regional roughness: 1.685035524034324, cone #123
# cut with cone #124
# regional roughness: 1.6745935556022866, cone #124
# cut with cone #125
# regional roughness: 1.6620588489160446, cone #125
# cut with cone #126
# regional roughness: 1.6969186475024836, cone #126
# cut with cone #127
# regional roughness: 1.6847145199574718, cone #127
# cut with cone #128
# regional roughness: 1.6729004624742314, cone #128
# cut with cone #129
# regional roughness: 1.6448930600380696, cone #129
# cut with cone #130
# regional roughness: 1.6113182131451165, cone #130
# cut with cone #131
# regional roughness: 1.6477036003440253, cone #131
# cut with cone #132
# regional roughness: 1.6821425362525158, cone #132
# cut with cone #133
# regional roughness: 1.710826065780669, cone #133
# cut with cone #134
# regional roughness: 1.696215914147851, cone #134
# cut with cone #135
# regional roughness: 1.683938393312782, cone #135
# cut with cone #136
# regional roughness: 1.6936999200652079, cone #136
# cut with cone #137
# regional roughness: 1.6926998259511261, cone #137
# cut with cone #138
# regional roughness: 1.6712849587715826, cone #138
# cut with cone #139
# regional roughness: 1.6653004753699943, cone #139
# cut with cone #140
# regional roughness: 1.6622530417659125, cone #140
# cut with cone #141
# regional roughness: 1.6672767986182597, cone #141
# cut with cone #142
# regional roughness: 1.6651717104672736, cone #142
# cut with cone #143
# regional roughness: 1.6851750913654782, cone #143
# cut with cone #144
# regional roughness: 1.692909579262185, cone #144
# cut with cone #145
# regional roughness: 1.661619450264187, cone #145
# cut with cone #146
# regional roughness: 1.6203075746584499, cone #146
# cut with cone #147
# regional roughness: 1.6303727685399514, cone #147
# cut with cone #148
# regional roughness: 1.633543710719913, cone #148
# cut with cone #149
# regional roughness: 1.602730563260614, cone #149
# cut with cone #150
# regional roughness: 1.5974479241108828, cone #150
# cut with cone #151
# regional roughness: 1.606927294949918, cone #151
# cut with cone #152
# regional roughness: 1.6692222554136271, cone #152
# cut with cone #153
# regional roughness: 1.6741439727321061, cone #153
# cut with cone #154
# regional roughness: 1.6569815780105766, cone #154
# cut with cone #155
# regional roughness: 1.6359573155585168, cone #155
# cut with cone #156
# regional roughness: 1.6227702340970438, cone #156
# cut with cone #157
# regional roughness: 1.6104979576178493, cone #157
# cut with cone #158
# regional roughness: 1.6200282714269527, cone #158
# cut with cone #159
# regional roughness: 1.6243195998398605, cone #159
# cut with cone #160
# regional roughness: 1.6355385401373268, cone #160
# cut with cone #161
# regional roughness: 1.6505068184532972, cone #161
# cut with cone #162
# regional roughness: 1.651024062077808, cone #162
# cut with cone #163
# regional roughness: 1.6039095930226328, cone #163
# cut with cone #164
# regional roughness: 1.5976903330595709, cone #164
# cut with cone #165
# regional roughness: 1.5931792460509018, cone #165
# cut with cone #166
# regional roughness: 1.5999468290438812, cone #166
# cut with cone #167
# regional roughness: 1.6013933396764894, cone #167
# cut with cone #168
# regional roughness: 1.6485504856925226, cone #168
# cut with cone #169
# regional roughness: 1.594038537298234, cone #169
# cut with cone #170
# regional roughness: 1.546185072319512, cone #170
# cut with cone #171
# regional roughness: 1.5252600842067172, cone #171
# cut with cone #172
# regional roughness: 1.562816383965826, cone #172
# cut with cone #173
# regional roughness: 1.5915952514318594, cone #173
# cut with cone #174
# regional roughness: 1.5729734064509597, cone #174
# cut with cone #175
# regional roughness: 1.5580903302632816, cone #175
# cut with cone #176
# regional roughness: 1.5598131684206478, cone #176
# cut with cone #177
# regional roughness: 1.520927892524602, cone #177
# cut with cone #178
# regional roughness: 1.5470275397922326, cone #178
# cut with cone #179
# regional roughness: 1.4917612142922252, cone #179
# cut with cone #180
# regional roughness: 1.4615074040362939, cone #180
# cut with cone #181
# regional roughness: 1.4809743411623144, cone #181
# cut with cone #182
# regional roughness: 1.5046041316224188, cone #182
# cut with cone #183
# regional roughness: 1.461141967000401, cone #183

# %%
plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(roughnesses_map)
plt.subplot(122)
plt.imshow(conevolumes_map)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>
